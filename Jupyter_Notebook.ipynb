# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # My Jupyter Notebook

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# **KABORE NIKIEMA JEAN-LUC**
# I want to a Data Scientist in a big tech company

# %% [markdown]
# *I am interested in data science because I am a big data lover*

# %% [markdown]
# ### In the below cell, it suppose to operate a multiplication operation between to number###

# %%
number1 = 56
number2 = 564
result = number1 * number2
print(result)

# %% [markdown]
# |Left |Center|Right|
# |:-----|:----:|----:|
# |1 |A |C |
# |2 |B |D |
# ***
# >quoted text
# ***
# ```python
# print('hello my peer');
# ```
